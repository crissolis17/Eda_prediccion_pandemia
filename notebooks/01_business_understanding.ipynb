# %%
# =============================================================================
# NOTEBOOK 1: COMPRENSIÓN DEL NEGOCIO
# Proyecto: Sistema Predictivo de Preparación para Pandemias
# Fase 1 CRISP-DM: Business Understanding
# =============================================================================

print("📋 PROYECTO: Sistema Predictivo de Preparación para Pandemias")
print("👥 Integrantes: Cristian Solis S.")
print("📅 Fecha: Septiembre 2025")
print("📚 Asignatura: Machine Learning (MLY0100)")
# Out:
# 📋 PROYECTO: Sistema Predictivo de Preparación para Pandemias
# 👥 Integrantes: Cristian Solis S.
# 📅 Fecha: Septiembre 2025
# 📚 Asignatura: Machine Learning (MLY0100)

# %%
# =============================================================================
# 1. DEFINIR OBJETIVOS DEL PROYECTO
# =============================================================================

print("="*70)
print("FASE 1: COMPRENSIÓN DEL NEGOCIO")
print("="*70)
print("\n1.1 PROBLEMA DE NEGOCIO\n")
print("""
Las pandemias representan amenazas catastróficas para la salud global.
Actualmente NO existe un sistema objetivo basado en datos para predecir
qué países estarán preparados para futuras pandemias.

PROBLEMAS ACTUALES:
- Evaluaciones subjetivas y poco científicas
- Datos estáticos que no capturan dinámicas temporales
- Información incompleta sobre factores de preparación
- Falta de sistema predictivo automatizado
""")
# Out:
# ...
# FASE 1: COMPRENSIÓN DEL NEGOCIO
# ...
#
# 1.1 PROBLEMA DE NEGOCIO
#
#
# Las pandemias representan amenazas catastróficas para la salud global.
# Actualmente NO existe un sistema objetivo basado en datos para predecir
# qué países estarán preparados para futuras pandemias.
#
# PROBLEMAS ACTUALES:
# - Evaluaciones subjetivas y poco científicas
# - Datos estáticos que no capturan dinámicas temporales
# - Información incompleta sobre factores de preparación
# - Falta de sistema predictivo automatizado

# %%
# Problema de negocio estructurado
problema = {
    'contexto': 'Amenaza global de pandemias',
    'problema_actual': 'Falta de sistema predictivo objetivo',
    'limitaciones': [
        'Evaluaciones subjetivas',
        'Datos estáticos',
        'Información incompleta'
    ]
}

print("\n📊 ESTRUCTURA DEL PROBLEMA:\n")
for key, value in problema.items():
    print(f"  {key.upper()}: {value}")
# Out:
# 📊 ESTRUCTURA DEL PROBLEMA:
#
#   CONTEXTO: Amenaza global de pandemias
#   PROBLEMA_ACTUAL: Falta de sistema predictivo objetivo
#   LIMITACIONES: ['Evaluaciones subjetivas', 'Datos estáticos', 'Información incompleta']

# %%
# Objetivo principal
print("\n" + "="*70)
print("1.2 OBJETIVO PRINCIPAL")
print("="*70)
print("""
Desarrollar un sistema predictivo que identifique qué países enfrentarán
mayores desafíos en futuras pandemias, permitiendo:

✓ Intervenciones preventivas tempranas
✓ Asignación eficiente de recursos internacionales
✓ Preparación proactiva ante emergencias sanitarias
""")
# Out:
# ...
# 1.2 OBJETIVO PRINCIPAL
# ...
#
# Desarrollar un sistema predictivo que identifique qué países enfrentarán
# mayores desafíos en futuras pandemias, permitiendo:
#
# ✓ Intervenciones preventivas tempranas
# ✓ Asignación eficiente de recursos internacionales
# ✓ Preparación proactiva ante emergencias sanitarias

# %%
# =============================================================================
# 2. OBJETIVOS ESPECÍFICOS (SMART)
# =============================================================================

objetivos_smart = {
    1: {
        'objetivo': 'Cuantificar preparación pandémica',
        'meta': 'Crear índice 0-100 para más de 150 países',
        'medible': 'Índice numérico validado',
        'alcanzable': 'Basado en datos disponibles',
        'relevante': 'Permite comparación objetiva',
        
    },
    2: {
        'objetivo': 'Predecir velocidad de respuesta',
        'meta': 'Estimar días para alcanzar 70% cobertura vacunal',
        'medible': 'Error < 30 días',
        'alcanzable': 'Con datos históricos de COVID-19',
        'relevante': 'Crítico para planificación',
        
    },
    3: {
        'objetivo': 'Clasificar estrategias nacionales',
        'meta': 'Identificar 5-7 arquetipos estratégicos',
        'medible': 'Clusters definidos y caracterizados',
        'alcanzable': 'Mediante clustering no supervisado',
        'relevante': 'Permite aprender de mejores prácticas',
        
    },
    4: {
        'objetivo': 'Identificar factores críticos',
        'meta': 'Determinar top 10 variables de preparación',
        'medible': 'Feature importance scores',
        'alcanzable': 'Con técnicas de ML',
        'relevante': 'Guía intervenciones específicas',
        
    }
}

print("\n🎯 OBJETIVOS SMART DEL PROYECTO:\n")
for num, obj in objetivos_smart.items():
    print(f"\n{num}. {obj['objetivo'].upper()}")
    print(f"   📍 Meta: {obj['meta']}")
    print(f"   📏 Medible: {obj['medible']}")
# Out:
# 🎯 OBJETIVOS SMART DEL PROYECTO:
#
#
# 1. CUANTIFICAR PREPARACIÓN PANDÉMICA
#    📍 Meta: Crear índice 0-100 para más de 150 países
#    📏 Medible: Índice numérico validado
#
# 2. PREDECIR VELOCIDAD DE RESPUESTA
#    📍 Meta: Estimar días para alcanzar 70% cobertura vacunal
#    📏 Medible: Error < 30 días
#
# 3. CLASIFICAR ESTRATEGIAS NACIONALES
#    📍 Meta: Identificar 5-7 arquetipos estratégicos
#    📏 Medible: Clusters definidos y caracterizados
#
# 4. IDENTIFICAR FACTORES CRÍTICOS
#    📍 Meta: Determinar top 10 variables de preparación
#    📏 Medible: Feature importance scores

# %%
# =============================================================================
# 3. STAKEHOLDERS Y VALOR ESPERADO
# =============================================================================

import pandas as pd

stakeholders = {
    'Stakeholder': ['OMS/ONU', 'Gobiernos Nacionales', 'Agencias de Cooperación', 
                    'Sector Farmacéutico', 'Investigadores'],
    'Interés Principal': [
        'Asignación eficiente de recursos',
        'Identificar vulnerabilidades propias',
        'Optimizar intervenciones',
        'Planificación de capacidad',
        'Datos y modelos'
    ],
    'Valor que Obtiene': [
        'Sistema para priorizar ayuda internacional',
        'Diagnóstico objetivo de preparación',
        'Identificación de países prioritarios',
        'Predicción de demanda por región',
        'Base de conocimiento científico'
    ]
}

df_stakeholders = pd.DataFrame(stakeholders)
print("\n👥 STAKEHOLDERS CLAVE:\n")
print(df_stakeholders.to_string(index=False))
# Out:
# 👥 STAKEHOLDERS CLAVE:
#
#             Stakeholder                    Interés Principal                          Valor que Obtiene
#                 OMS/ONU     Asignación eficiente de recursos Sistema para priorizar ayuda internacional
#    Gobiernos Nacionales Identificar vulnerabilidades propias        Diagnóstico objetivo de preparación
# Agencias de Cooperación             Optimizar intervenciones      Identificación de países prioritarios
#     Sector Farmacéutico           Planificación de capacidad           Predicción de demanda por región
#          Investigadores                      Datos y modelos            Base de conocimiento científico

# %%
# =============================================================================
# 4. EVALUACIÓN DE LA SITUACIÓN
# =============================================================================

print("\n" + "="*70)
print("EVALUACIÓN DE LA SITUACIÓN")
print("="*70)

# Recursos disponibles
recursos = {
    'datos': [
        'COVID-19 compact dataset (521,908 registros, 61 variables)',
        'Vacunación global (203,057 registros, 29 variables)',
        'Vacunación por edad (datos demográficos)',
        'Vacunación por fabricante (datos de producción)'
    ],
    'herramientas': [
        'Framework Kedro para MLOps',
        'Python + scikit-learn para ML',
        'Jupyter Notebooks para análisis',
        'Git para control de versiones'
    ],
    'equipo': [
        'Estudiantes con conocimientos en ML',
        'Acceso a documentación y tutoriales',
        'Tiempo: 4 semanas'
    ]
}

print("\n📦 RECURSOS DISPONIBLES:\n")
for categoria, items in recursos.items():
    print(f"\n{categoria.upper()}:")
    for item in items:
        print(f"  • {item}")
# Out:
# ...
# EVALUACIÓN DE LA SITUACIÓN
# ...
#
# 📦 RECURSOS DISPONIBLES:
#
#
# DATOS:
#   • COVID-19 compact dataset (521,908 registros, 61 variables)
#   • Vacunación global (203,057 registros, 29 variables)
#   • Vacunación por edad (datos demográficos)
#   • Vacunación por fabricante (datos de producción)
#
# HERRAMIENTAS:
#   • Framework Kedro para MLOps
#   • Python + scikit-learn para ML
#   • Jupyter Notebooks para análisis
#   • Git para control de versiones
#
# EQUIPO:
#   • Estudiantes con conocimientos en ML
#   • Acceso a documentación y tutoriales
#   • Tiempo: 4 semanas

# %%
# =============================================================================
# 5. OBJETIVOS DE MACHINE LEARNING
# =============================================================================

print("\n" + "="*70)
print("OBJETIVOS DE MACHINE LEARNING")
print("="*70)

ml_problems = {
    'Problema 1: Regresión': {
        'Target': 'Días para alcanzar 70% de cobertura vacunal',
        'Features': ['Capacidad sanitaria', 'PIB per cápita', 'Infraestructura', 'Demografía'],
        'Algoritmos': ['Random Forest', 'Gradient Boosting', 'XGBoost'],
        'Métrica': 'MAE < 30 días'
    },
    'Problema 2: Clasificación': {
        'Target': 'Nivel de preparación (Alto/Medio/Bajo riesgo)',
        'Features': ['HDI', 'Capacidad de respuesta', 'Recursos sanitarios'],
        'Algoritmos': ['Logistic Regression', 'Random Forest', 'SVM'],
        'Métrica': 'Accuracy > 70%'
    },
    'Problema 3: Clustering': {
        'Target': 'Arquetipos de respuesta (5-7 grupos)',
        'Features': ['Patrones temporales', 'Medidas de contención', 'Velocidad inicial'],
        'Algoritmos': ['K-Means', 'Hierarchical', 'DBSCAN'],
        'Métrica': 'Silhouette Score > 0.5'
    }
}

for problema, detalles in ml_problems.items():
    print(f"\n{problema}")
    print("-" * 50)
    for key, value in detalles.items():
        print(f"  {key}: {value}")
# Out:
# ...
# OBJETIVOS DE MACHINE LEARNING
# ...
#
# Problema 1: Regresión
# --------------------------------------------------
#   Target: Días para alcanzar 70% de cobertura vacunal
#   Features: ['Capacidad sanitaria', 'PIB per cápita', 'Infraestructura', 'Demografía']
#   Algoritmos: ['Random Forest', 'Gradient Boosting', 'XGBoost']
#   Métrica: MAE < 30 días
#
# Problema 2: Clasificación
# --------------------------------------------------
#   Target: Nivel de preparación (Alto/Medio/Bajo riesgo)
#   Features: ['HDI', 'Capacidad de respuesta', 'Recursos sanitarios']
#   Algoritmos: ['Logistic Regression', 'Random Forest', 'SVM']
#   Métrica: Accuracy > 70%
#
# Problema 3: Clustering
# --------------------------------------------------
#   Target: Arquetipos de respuesta (5-7 grupos)
#   Features: ['Patrones temporales', 'Medidas de contención', 'Velocidad inicial']
#   Algoritmos: ['K-Means', 'Hierarchical', 'DBSCAN']
#   Métrica: Silhouette Score > 0.5

# %%
# =============================================================================
# 8. RESUMEN EJECUTIVO FASE 1
# =============================================================================

print("\n" + "="*70)
print("RESUMEN EJECUTIVO - FASE 1")
print("="*70)

resumen = """
PROYECTO: Sistema Predictivo de Preparación para Pandemias

PROBLEMA: Falta de herramientas objetivas para predecir preparación pandémica

SOLUCIÓN PROPUESTA: Sistema de ML con 3 componentes:
  1. Regresión: Predecir velocidad de respuesta (días a 70% vacunación)
  2. Clasificación: Determinar nivel de riesgo (Alto/Medio/Bajo)
  3. Clustering: Identificar arquetipos estratégicos

DATOS DISPONIBLES: 4 datasets (750K+ registros, 262 países)

TECNOLOGÍA: Kedro + Python + scikit-learn

TIMELINE: 4 semanas

VALOR ESPERADO:
  - Para OMS: Priorización objetiva de recursos
  - Para gobiernos: Diagnóstico de vulnerabilidades
  - Para investigadores: Base de conocimiento reproducible
"""

print(resumen)
print("\n✅ FASE 1 COMPLETADA")
print("📊 Próxima fase: Comprensión de los Datos (EDA)")
# Out:
# ...
# RESUMEN EJECUTIVO - FASE 1
# ...
#
# PROYECTO: Sistema Predictivo de Preparación para Pandemias
#
# PROBLEMA: Falta de herramientas objetivas para predecir preparación pandémica
#
# SOLUCIÓN PROPUESTA: Sistema de ML con 3 componentes:
#   1. Regresión: Predecir velocidad de respuesta (días a 70% vacunación)
#   2. Clasificación: Determinar nivel de riesgo (Alto/Medio/Bajo)
#   3. Clustering: Identificar arquetipos estratégicos
#
# DATOS DISPONIBLES: 4 datasets (750K+ registros, 262 países)
#
# TECNOLOGÍA: Kedro + Python + scikit-learn
#
# TIMELINE: 4 semanas
#
# VALOR ESPERADO:
#   - Para OMS: Priorización objetiva de recursos
#   - Para gobiernos: Diagnóstico de vulnerabilidades
#   - Para investigadores: Base de conocimiento reproducible
#
#
# ✅ FASE 1 COMPLETADA
# 📊 Próxima fase: Comprensión de los Datos (EDA)
